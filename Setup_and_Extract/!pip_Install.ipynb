# %%
# !pip install pandas
# !pip install scipy==1.5.4
# !pip install shap==0.46.0
# !pip install --upgrade pip setuptools wheel
# !pip install pycaret==3.0.0
# Out:
# Requirement already satisfied: pandas in c:\users\65811\jupyter\lib\site-packages (1.5.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\65811\jupyter\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\65811\jupyter\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\65811\jupyter\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\65811\jupyter\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting scipy==1.5.4
#   Using cached scipy-1.5.4.tar.gz (25.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [611 lines of output]
#       Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#       Collecting wheel
#         Using cached wheel-0.44.0-py3-none-any.whl (67 kB)
#       Collecting setuptools
#         Using cached setuptools-75.2.0-py3-none-any.whl (1.2 MB)
#       Collecting Cython>=0.29.18
#         Using cached Cython-3.0.11-cp310-cp310-win_amd64.whl (2.8 MB)
#       Collecting numpy==1.17.3
#         Using cached numpy-1.17.3.zip (6.4 MB)
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting pybind11>=2.4.3
#         Using cached pybind11-2.13.6-py3-none-any.whl (243 kB)
#       Building wheels for collected packages: numpy
#         Building wheel for numpy (setup.py): started
#         Building wheel for numpy (setup.py): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × python setup.py bdist_wheel did not run successfully.
#         │ exit code: 1
#         ╰─> [268 lines of output]
#             Running from numpy source directory.
#             blas_opt_info:
#             blas_mkl_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries mkl_rt not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             blis_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries blis not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             openblas_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries openblas not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#             get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#             customize GnuFCompiler
#             Could not locate executable g77
#             Could not locate executable f77
#             customize IntelVisualFCompiler
#             Could not locate executable ifort
#             Could not locate executable ifl
#             customize AbsoftFCompiler
#             Could not locate executable f90
#             customize CompaqVisualFCompiler
#             Could not locate executable DF
#             customize IntelItaniumVisualFCompiler
#             Could not locate executable efl
#             customize Gnu95FCompiler
#             Could not locate executable gfortran
#             Could not locate executable f95
#             customize G95FCompiler
#             Could not locate executable g95
#             customize IntelEM64VisualFCompiler
#             customize IntelEM64TFCompiler
#             Could not locate executable efort
#             Could not locate executable efc
#             customize PGroupFlangCompiler
#             Could not locate executable flang
#             don't know how to compile Fortran code on platform 'nt'
#               NOT AVAILABLE
#
#             atlas_3_10_blas_threads_info:
#             Setting PTATLAS=ATLAS
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries tatlas not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             atlas_3_10_blas_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries satlas not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             atlas_blas_threads_info:
#             Setting PTATLAS=ATLAS
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             atlas_blas_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries f77blas,cblas,atlas not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             accelerate_info:
#               NOT AVAILABLE
#
#             C:\Users\65811\AppData\Local\Temp\pip-install-8s_np82d\numpy_cfb66b496e7246faaa612261d173095a\numpy\distutils\system_info.py:690: UserWarning:
#                 Optimized (vendor) Blas libraries are not found.
#                 Falls back to netlib Blas library which has worse performance.
#                 A better performance should be easily gained by switching
#                 Blas library.
#               self.calc_info()
#             blas_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries blas not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             C:\Users\65811\AppData\Local\Temp\pip-install-8s_np82d\numpy_cfb66b496e7246faaa612261d173095a\numpy\distutils\system_info.py:690: UserWarning:
#                 Blas (http://www.netlib.org/blas/) libraries not found.
#                 Directories to search for the libraries can be specified in the
#                 numpy/distutils/site.cfg file (section [blas]) or by setting
#                 the BLAS environment variable.
#               self.calc_info()
#             blas_src_info:
#               NOT AVAILABLE
#
#             C:\Users\65811\AppData\Local\Temp\pip-install-8s_np82d\numpy_cfb66b496e7246faaa612261d173095a\numpy\distutils\system_info.py:690: UserWarning:
#                 Blas (http://www.netlib.org/blas/) sources not found.
#                 Directories to search for the sources can be specified in the
#                 numpy/distutils/site.cfg file (section [blas_src]) or by setting
#                 the BLAS_SRC environment variable.
#               self.calc_info()
#               NOT AVAILABLE
#
#             'svnversion' is not recognized as an internal or external command,
#             operable program or batch file.
#             non-existing path in 'numpy\\distutils': 'site.cfg'
#             lapack_opt_info:
#             lapack_mkl_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries mkl_rt not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             openblas_lapack_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries openblas not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             openblas_clapack_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries openblas,lapack not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             flame_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries flame not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             atlas_3_10_threads_info:
#             Setting PTATLAS=ATLAS
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Users\65811\jupyter\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries tatlas,tatlas not found in C:\Users\65811\jupyter\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries tatlas,tatlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Users\65811\jupyter\libs
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries tatlas,tatlas not found in C:\Users\65811\jupyter\libs
#             <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#               NOT AVAILABLE
#
#             atlas_3_10_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Users\65811\jupyter\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries satlas,satlas not found in C:\Users\65811\jupyter\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries satlas,satlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Users\65811\jupyter\libs
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries satlas,satlas not found in C:\Users\65811\jupyter\libs
#             <class 'numpy.distutils.system_info.atlas_3_10_info'>
#               NOT AVAILABLE
#
#             atlas_threads_info:
#             Setting PTATLAS=ATLAS
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Users\65811\jupyter\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries ptf77blas,ptcblas,atlas not found in C:\Users\65811\jupyter\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries ptf77blas,ptcblas,atlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Users\65811\jupyter\libs
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries ptf77blas,ptcblas,atlas not found in C:\Users\65811\jupyter\libs
#             <class 'numpy.distutils.system_info.atlas_threads_info'>
#               NOT AVAILABLE
#
#             atlas_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Users\65811\jupyter\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries f77blas,cblas,atlas not found in C:\Users\65811\jupyter\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries f77blas,cblas,atlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Users\65811\jupyter\libs
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries f77blas,cblas,atlas not found in C:\Users\65811\jupyter\libs
#             <class 'numpy.distutils.system_info.atlas_info'>
#               NOT AVAILABLE
#
#             lapack_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             C:\Users\65811\AppData\Local\Temp\pip-install-8s_np82d\numpy_cfb66b496e7246faaa612261d173095a\numpy\distutils\system_info.py:1712: UserWarning:
#                 Lapack (http://www.netlib.org/lapack/) libraries not found.
#                 Directories to search for the libraries can be specified in the
#                 numpy/distutils/site.cfg file (section [lapack]) or by setting
#                 the LAPACK environment variable.
#               if getattr(self, '_calc_info_{}'.format(lapack))():
#             lapack_src_info:
#               NOT AVAILABLE
#
#             C:\Users\65811\AppData\Local\Temp\pip-install-8s_np82d\numpy_cfb66b496e7246faaa612261d173095a\numpy\distutils\system_info.py:1712: UserWarning:
#                 Lapack (http://www.netlib.org/lapack/) sources not found.
#                 Directories to search for the sources can be specified in the
#                 numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#                 the LAPACK_SRC environment variable.
#               if getattr(self, '_calc_info_{}'.format(lapack))():
#               NOT AVAILABLE
#
#             C:\Users\65811\jupyter\lib\site-packages\setuptools\_distutils\dist.py:265: UserWarning: Unknown distribution option: 'define_macros'
#               warnings.warn(msg)
#             running bdist_wheel
#             running build
#             running config_cc
#             unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#             running config_fc
#             unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#             running build_src
#             build_src
#             building py_modules sources
#             creating build
#             creating build\src.win-amd64-3.1
#             creating build\src.win-amd64-3.1\numpy
#             creating build\src.win-amd64-3.1\numpy\distutils
#             building library "npymath" sources
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#         ERROR: Failed building wheel for numpy
#         Running setup.py clean for numpy
#         error: subprocess-exited-with-error
#
#         × python setup.py clean did not run successfully.
#         │ exit code: 1
#         ╰─> [10 lines of output]
#             Running from numpy source directory.
#
#             `setup.py clean` is not supported, use one of the following instead:
#
#               - `git clean -xdf` (cleans all files)
#               - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                                   files that aren't checked into the git repo)
#
#             Add `--force` to your command to use it anyway if you must (unsupported).
#
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#         ERROR: Failed cleaning build dir for numpy
#       Failed to build numpy
#       Installing collected packages: wheel, setuptools, pybind11, numpy, Cython
#         Running setup.py install for numpy: started
#         Running setup.py install for numpy: finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × Running setup.py install for numpy did not run successfully.
#         │ exit code: 1
#         ╰─> [275 lines of output]
#             Running from numpy source directory.
#
#             Note: if you need reliable uninstall behavior, then install
#             with pip instead of using `setup.py install`:
#
#               - `pip install .`       (from a git repo or downloaded source
#                                        release)
#               - `pip install numpy`   (last NumPy release on PyPi)
#
#
#             blas_opt_info:
#             blas_mkl_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries mkl_rt not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             blis_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries blis not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             openblas_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries openblas not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#             get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#             customize GnuFCompiler
#             Could not locate executable g77
#             Could not locate executable f77
#             customize IntelVisualFCompiler
#             Could not locate executable ifort
#             Could not locate executable ifl
#             customize AbsoftFCompiler
#             Could not locate executable f90
#             customize CompaqVisualFCompiler
#             Could not locate executable DF
#             customize IntelItaniumVisualFCompiler
#             Could not locate executable efl
#             customize Gnu95FCompiler
#             Could not locate executable gfortran
#             Could not locate executable f95
#             customize G95FCompiler
#             Could not locate executable g95
#             customize IntelEM64VisualFCompiler
#             customize IntelEM64TFCompiler
#             Could not locate executable efort
#             Could not locate executable efc
#             customize PGroupFlangCompiler
#             Could not locate executable flang
#             don't know how to compile Fortran code on platform 'nt'
#               NOT AVAILABLE
#
#             atlas_3_10_blas_threads_info:
#             Setting PTATLAS=ATLAS
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries tatlas not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             atlas_3_10_blas_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries satlas not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             atlas_blas_threads_info:
#             Setting PTATLAS=ATLAS
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             atlas_blas_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries f77blas,cblas,atlas not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             accelerate_info:
#               NOT AVAILABLE
#
#             C:\Users\65811\AppData\Local\Temp\pip-install-8s_np82d\numpy_cfb66b496e7246faaa612261d173095a\numpy\distutils\system_info.py:690: UserWarning:
#                 Optimized (vendor) Blas libraries are not found.
#                 Falls back to netlib Blas library which has worse performance.
#                 A better performance should be easily gained by switching
#                 Blas library.
#               self.calc_info()
#             blas_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries blas not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             C:\Users\65811\AppData\Local\Temp\pip-install-8s_np82d\numpy_cfb66b496e7246faaa612261d173095a\numpy\distutils\system_info.py:690: UserWarning:
#                 Blas (http://www.netlib.org/blas/) libraries not found.
#                 Directories to search for the libraries can be specified in the
#                 numpy/distutils/site.cfg file (section [blas]) or by setting
#                 the BLAS environment variable.
#               self.calc_info()
#             blas_src_info:
#               NOT AVAILABLE
#
#             C:\Users\65811\AppData\Local\Temp\pip-install-8s_np82d\numpy_cfb66b496e7246faaa612261d173095a\numpy\distutils\system_info.py:690: UserWarning:
#                 Blas (http://www.netlib.org/blas/) sources not found.
#                 Directories to search for the sources can be specified in the
#                 numpy/distutils/site.cfg file (section [blas_src]) or by setting
#                 the BLAS_SRC environment variable.
#               self.calc_info()
#               NOT AVAILABLE
#
#             'svnversion' is not recognized as an internal or external command,
#             operable program or batch file.
#             non-existing path in 'numpy\\distutils': 'site.cfg'
#             lapack_opt_info:
#             lapack_mkl_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries mkl_rt not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             openblas_lapack_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries openblas not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             openblas_clapack_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries openblas,lapack not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             flame_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries flame not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             atlas_3_10_threads_info:
#             Setting PTATLAS=ATLAS
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Users\65811\jupyter\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries tatlas,tatlas not found in C:\Users\65811\jupyter\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries tatlas,tatlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Users\65811\jupyter\libs
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries tatlas,tatlas not found in C:\Users\65811\jupyter\libs
#             <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#               NOT AVAILABLE
#
#             atlas_3_10_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Users\65811\jupyter\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries satlas,satlas not found in C:\Users\65811\jupyter\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries satlas,satlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Users\65811\jupyter\libs
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries satlas,satlas not found in C:\Users\65811\jupyter\libs
#             <class 'numpy.distutils.system_info.atlas_3_10_info'>
#               NOT AVAILABLE
#
#             atlas_threads_info:
#             Setting PTATLAS=ATLAS
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Users\65811\jupyter\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries ptf77blas,ptcblas,atlas not found in C:\Users\65811\jupyter\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries ptf77blas,ptcblas,atlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Users\65811\jupyter\libs
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries ptf77blas,ptcblas,atlas not found in C:\Users\65811\jupyter\libs
#             <class 'numpy.distutils.system_info.atlas_threads_info'>
#               NOT AVAILABLE
#
#             atlas_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Users\65811\jupyter\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries f77blas,cblas,atlas not found in C:\Users\65811\jupyter\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries f77blas,cblas,atlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Users\65811\jupyter\libs
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries f77blas,cblas,atlas not found in C:\Users\65811\jupyter\libs
#             <class 'numpy.distutils.system_info.atlas_info'>
#               NOT AVAILABLE
#
#             lapack_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack not found in ['C:\\Users\\65811\\jupyter\\lib', 'C:\\', 'C:\\Users\\65811\\jupyter\\libs']
#               NOT AVAILABLE
#
#             C:\Users\65811\AppData\Local\Temp\pip-install-8s_np82d\numpy_cfb66b496e7246faaa612261d173095a\numpy\distutils\system_info.py:1712: UserWarning:
#                 Lapack (http://www.netlib.org/lapack/) libraries not found.
#                 Directories to search for the libraries can be specified in the
#                 numpy/distutils/site.cfg file (section [lapack]) or by setting
#                 the LAPACK environment variable.
#               if getattr(self, '_calc_info_{}'.format(lapack))():
#             lapack_src_info:
#               NOT AVAILABLE
#
#             C:\Users\65811\AppData\Local\Temp\pip-install-8s_np82d\numpy_cfb66b496e7246faaa612261d173095a\numpy\distutils\system_info.py:1712: UserWarning:
#                 Lapack (http://www.netlib.org/lapack/) sources not found.
#                 Directories to search for the sources can be specified in the
#                 numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#                 the LAPACK_SRC environment variable.
#               if getattr(self, '_calc_info_{}'.format(lapack))():
#               NOT AVAILABLE
#
#             C:\Users\65811\jupyter\lib\site-packages\setuptools\_distutils\dist.py:265: UserWarning: Unknown distribution option: 'define_macros'
#               warnings.warn(msg)
#             running install
#             C:\Users\65811\jupyter\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#               warnings.warn(
#             running build
#             running config_cc
#             unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#             running config_fc
#             unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#             running build_src
#             build_src
#             building py_modules sources
#             building library "npymath" sources
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: legacy-install-failure
#
#       × Encountered error while trying to install package.
#       ╰─> numpy
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for output from the failure.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Requirement already satisfied: shap==0.46.0 in c:\users\65811\jupyter\lib\site-packages (0.46.0)
# Requirement already satisfied: numpy in c:\users\65811\jupyter\lib\site-packages (from shap==0.46.0) (1.23.5)
# Requirement already satisfied: slicer==0.0.8 in c:\users\65811\jupyter\lib\site-packages (from shap==0.46.0) (0.0.8)
# Requirement already satisfied: numba in c:\users\65811\jupyter\lib\site-packages (from shap==0.46.0) (0.56.4)
# Requirement already satisfied: cloudpickle in c:\users\65811\jupyter\lib\site-packages (from shap==0.46.0) (2.0.0)
# Requirement already satisfied: pandas in c:\users\65811\jupyter\lib\site-packages (from shap==0.46.0) (1.5.3)
# Requirement already satisfied: scikit-learn in c:\users\65811\jupyter\lib\site-packages (from shap==0.46.0) (1.2.1)
# Requirement already satisfied: scipy in c:\users\65811\jupyter\lib\site-packages (from shap==0.46.0) (1.10.0)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\65811\jupyter\lib\site-packages (from shap==0.46.0) (4.64.1)
# Requirement already satisfied: packaging>20.9 in c:\users\65811\jupyter\lib\site-packages (from shap==0.46.0) (22.0)
# Requirement already satisfied: colorama in c:\users\65811\jupyter\lib\site-packages (from tqdm>=4.27.0->shap==0.46.0) (0.4.6)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\65811\jupyter\lib\site-packages (from numba->shap==0.46.0) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\65811\jupyter\lib\site-packages (from numba->shap==0.46.0) (65.6.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\65811\jupyter\lib\site-packages (from pandas->shap==0.46.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\65811\jupyter\lib\site-packages (from pandas->shap==0.46.0) (2022.7)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\65811\jupyter\lib\site-packages (from scikit-learn->shap==0.46.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\65811\jupyter\lib\site-packages (from scikit-learn->shap==0.46.0) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\65811\jupyter\lib\site-packages (from python-dateutil>=2.8.1->pandas->shap==0.46.0) (1.16.0)
# Requirement already satisfied: pip in c:\users\65811\jupyter\lib\site-packages (22.3.1)
# Collecting pip
#   Using cached pip-24.2-py3-none-any.whl (1.8 MB)
# Requirement already satisfied: setuptools in c:\users\65811\jupyter\lib\site-packages (65.6.3)
# Collecting setuptools
#   Using cached setuptools-75.2.0-py3-none-any.whl (1.2 MB)
# Requirement already satisfied: wheel in c:\users\65811\jupyter\lib\site-packages (0.38.4)
# Collecting wheel
#   Using cached wheel-0.44.0-py3-none-any.whl (67 kB)
# ERROR: To modify pip, please run the following command:
# C:\Users\65811\jupyter\python.exe -m pip install --upgrade pip setuptools wheel
# Requirement already satisfied: pycaret==3.0.0 in c:\users\65811\jupyter\lib\site-packages (3.0.0)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (2.1.0)
# Requirement already satisfied: pandas<1.6.0,>=1.3.0 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (1.5.3)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (0.2.1)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (8.10.0)
# Requirement already satisfied: scipy<2.0.0 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (1.10.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (5.7.0)
# Requirement already satisfied: pyod>=1.0.8 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (2.0.2)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (5.9.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (2.1.1)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (3.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (4.5.0)
# Requirement already satisfied: schemdraw>=0.14 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (0.19)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (2.6.4)
# Requirement already satisfied: xxhash in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (3.5.0)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (0.10.0)
# Requirement already satisfied: numpy<1.25,>=1.21 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (1.23.5)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (1.5)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (2.0.4)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (4.64.1)
# Requirement already satisfied: cloudpickle in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (2.0.0)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (0.10.1)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (8.5.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (0.56.4)
# Requirement already satisfied: tbats>=1.1.0 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (1.1.3)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (7.6.5)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (5.9.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (1.4.2)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (0.13.5)
# Requirement already satisfied: jinja2>=1.2 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (3.1.2)
# Requirement already satisfied: requests>=2.27.1 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (2.31.0)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (0.3.7)
# Requirement already satisfied: sktime>=0.16.1 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (0.34.0)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\65811\jupyter\lib\site-packages (from pycaret==3.0.0) (1.2.1)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\65811\jupyter\lib\site-packages (from category-encoders>=2.4.0->pycaret==3.0.0) (0.5.3)
# Requirement already satisfied: packaging in c:\users\65811\jupyter\lib\site-packages (from deprecation>=2.1.0->pycaret==3.0.0) (22.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\65811\jupyter\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret==3.0.0) (2.2.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\65811\jupyter\lib\site-packages (from importlib-metadata>=4.12.0->pycaret==3.0.0) (3.20.2)
# Requirement already satisfied: colorama in c:\users\65811\jupyter\lib\site-packages (from ipython>=5.5.0->pycaret==3.0.0) (0.4.6)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\65811\jupyter\lib\site-packages (from ipython>=5.5.0->pycaret==3.0.0) (2.11.2)
# Requirement already satisfied: decorator in c:\users\65811\jupyter\lib\site-packages (from ipython>=5.5.0->pycaret==3.0.0) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\65811\jupyter\lib\site-packages (from ipython>=5.5.0->pycaret==3.0.0) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\65811\jupyter\lib\site-packages (from ipython>=5.5.0->pycaret==3.0.0) (0.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\65811\jupyter\lib\site-packages (from ipython>=5.5.0->pycaret==3.0.0) (3.0.36)
# Requirement already satisfied: matplotlib-inline in c:\users\65811\jupyter\lib\site-packages (from ipython>=5.5.0->pycaret==3.0.0) (0.1.6)
# Requirement already satisfied: backcall in c:\users\65811\jupyter\lib\site-packages (from ipython>=5.5.0->pycaret==3.0.0) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\65811\jupyter\lib\site-packages (from ipython>=5.5.0->pycaret==3.0.0) (0.18.1)
# Requirement already satisfied: traitlets>=5 in c:\users\65811\jupyter\lib\site-packages (from ipython>=5.5.0->pycaret==3.0.0) (5.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\65811\jupyter\lib\site-packages (from ipywidgets>=7.6.5->pycaret==3.0.0) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\65811\jupyter\lib\site-packages (from ipywidgets>=7.6.5->pycaret==3.0.0) (6.19.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\65811\jupyter\lib\site-packages (from ipywidgets>=7.6.5->pycaret==3.0.0) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\65811\jupyter\lib\site-packages (from ipywidgets>=7.6.5->pycaret==3.0.0) (1.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\65811\jupyter\lib\site-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\65811\jupyter\lib\site-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\65811\jupyter\lib\site-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\65811\jupyter\lib\site-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\65811\jupyter\lib\site-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\65811\jupyter\lib\site-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\65811\jupyter\lib\site-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (4.25.0)
# Requirement already satisfied: jupyter-core in c:\users\65811\jupyter\lib\site-packages (from nbformat>=4.2.0->pycaret==3.0.0) (5.2.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\65811\jupyter\lib\site-packages (from nbformat>=4.2.0->pycaret==3.0.0) (4.17.3)
# Requirement already satisfied: fastjsonschema in c:\users\65811\jupyter\lib\site-packages (from nbformat>=4.2.0->pycaret==3.0.0) (2.16.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\65811\jupyter\lib\site-packages (from numba>=0.55.0->pycaret==3.0.0) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\65811\jupyter\lib\site-packages (from numba>=0.55.0->pycaret==3.0.0) (65.6.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\65811\jupyter\lib\site-packages (from pandas<1.6.0,>=1.3.0->pycaret==3.0.0) (2022.7)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\65811\jupyter\lib\site-packages (from plotly>=5.0.0->pycaret==3.0.0) (8.0.1)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\65811\jupyter\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret==3.0.0) (0.1.3)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\65811\jupyter\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret==3.0.0) (3.10.10)
# Requirement already satisfied: dash>=2.9.0 in c:\users\65811\jupyter\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.18.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\65811\jupyter\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret==3.0.0) (3.0.11)
# Requirement already satisfied: urllib3 in c:\users\65811\jupyter\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret==3.0.0) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\65811\jupyter\lib\site-packages (from requests>=2.27.1->pycaret==3.0.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\65811\jupyter\lib\site-packages (from requests>=2.27.1->pycaret==3.0.0) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\65811\jupyter\lib\site-packages (from requests>=2.27.1->pycaret==3.0.0) (2.0.4)
# Requirement already satisfied: scikit-base<0.12.0,>=0.6.1 in c:\users\65811\jupyter\lib\site-packages (from sktime>=0.16.1->pycaret==3.0.0) (0.11.0)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\65811\jupyter\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.2.2)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\65811\jupyter\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\65811\jupyter\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\65811\jupyter\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (4.11.0)
# Requirement already satisfied: nest-asyncio in c:\users\65811\jupyter\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (1.5.6)
# Requirement already satisfied: retrying in c:\users\65811\jupyter\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (1.3.4)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\65811\jupyter\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.2.2)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\65811\jupyter\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.0.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\65811\jupyter\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret==3.0.0) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\65811\jupyter\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret==3.0.0) (23.2.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\65811\jupyter\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret==3.0.0) (1.5.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\65811\jupyter\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret==3.0.0) (0.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\65811\jupyter\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret==3.0.0) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\65811\jupyter\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret==3.0.0) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\65811\jupyter\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.0.0) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\65811\jupyter\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.0.0) (0.18.0)
# Requirement already satisfied: six in c:\users\65811\jupyter\lib\site-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret==3.0.0) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\65811\jupyter\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret==3.0.0) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\65811\jupyter\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (6.5.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\65811\jupyter\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret==3.0.0) (2.5.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\65811\jupyter\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret==3.0.0) (305.1)
# Requirement already satisfied: executing in c:\users\65811\jupyter\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret==3.0.0) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\65811\jupyter\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret==3.0.0) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\65811\jupyter\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret==3.0.0) (2.0.5)
# Requirement already satisfied: click>=8.0 in c:\users\65811\jupyter\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (8.0.4)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\65811\jupyter\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.0.1)
# Requirement already satisfied: entrypoints in c:\users\65811\jupyter\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret==3.0.0) (0.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\65811\jupyter\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\65811\jupyter\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\65811\jupyter\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.5.2)
# Requirement already satisfied: nbconvert>=5 in c:\users\65811\jupyter\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (6.5.4)
# Requirement already satisfied: argon2-cffi in c:\users\65811\jupyter\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\65811\jupyter\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.17.1)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\65811\jupyter\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\65811\jupyter\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.23.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\65811\jupyter\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.5.13)
# Requirement already satisfied: lxml in c:\users\65811\jupyter\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\65811\jupyter\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\65811\jupyter\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\65811\jupyter\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.7.1)
# Requirement already satisfied: tinycss2 in c:\users\65811\jupyter\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\65811\jupyter\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\65811\jupyter\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.1.2)
# Requirement already satisfied: bleach in c:\users\65811\jupyter\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (4.1.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\65811\jupyter\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\65811\jupyter\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (21.2.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\65811\jupyter\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\65811\jupyter\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\65811\jupyter\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\65811\jupyter\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\65811\jupyter\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\65811\jupyter\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\65811\jupyter\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret==3.0.0) (2.21)
